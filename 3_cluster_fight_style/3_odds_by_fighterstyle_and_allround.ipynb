# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('../2_data_preparation/cleaned_data.csv')
clustered = pd.read_csv('data_clustered.csv')

# %%
clustered = clustered[['name', 'cluster']]
clustered
# Out:
#                    name  cluster
# 0         Lerone Murphy        4
# 1         Edson Barboza        4
# 2        Khaos Williams        4
# 3       Carlston Harris        2
# 4        Themba Gorimbo        2
# ...                 ...      ...
# 2391         Nick Sanzo        3
# 2392         Jim Mullen        3
# 2393  Yoshiki Takahashi        1
# 2394      Wallid Ismail        1
# 2395     Rainy Martinez        3
#
# [2396 rows x 2 columns]

# %%
data['winner'].value_counts()
# Out:
# winner
# f1    7289
# 0      111
# Name: count, dtype: int64

# %%
# filter data where clear decision
data = data[data['winner'] == 'f1']
data['winner'].value_counts()
# Out:
# winner
# f1    7289
# Name: count, dtype: int64

# %%
data['method'].value_counts()
# Out:
# method
# Decision - Unanimous    2645
# KO/TKO                  2443
# Submission              1435
# Decision - Split         766
# Name: count, dtype: int64

# %%
data = data[data['method'].isin(['Decision - Unanimous', 'Decision - Split'])]

# %%
data['method'].value_counts()
# Out:
# method
# Decision - Unanimous    2645
# Decision - Split         766
# Name: count, dtype: int64

# %%
# Merge the cluster column from clustered DataFrame based on fighter names (f1 and f2)
data = pd.merge(data, clustered[['name', 'cluster']], left_on='f1', right_on='name', how='left')
data.rename(columns={'cluster': 'winner_cluster'}, inplace=True)

data = pd.merge(data, clustered[['name', 'cluster']], left_on='f2', right_on='name', how='left')
data.rename(columns={'cluster': 'loser_cluster'}, inplace=True)

# %%
odds_df = data[['winner_cluster', 'loser_cluster']]

# %%
odds_df.head(2)
# Out:
#    winner_cluster  loser_cluster
# 0               4              4
# 1               2              2

# %%
# filter data where clear decision
data = data[data['winner'] == 'f1']
data['winner'].value_counts()
# Out:
# winner
# f1    3411
# Name: count, dtype: int64

# %%
odds_df['winner_cluster'].value_counts()
# Out:
# winner_cluster
# 2    1669
# 4    1491
# 1     237
# 0       7
# 3       7
# Name: count, dtype: int64

# %%
import matplotlib.cm as cm

# Group by winner and loser clusters to count the number of wins and losses
win_counts = odds_df.groupby(['winner_cluster', 'loser_cluster']).size().unstack(fill_value=0)
loss_counts = odds_df.groupby(['loser_cluster', 'winner_cluster']).size().unstack(fill_value=0)

# Calculate win percentage by cluster matchup
win_percentage = (win_counts / (win_counts + loss_counts)) * 100
# Round win percentages to nearest integer
win_percentage_rounded = win_percentage.round()

# Display win percentages by cluster matchup
win_percentage_rounded.style.background_gradient(cmap='Blues', axis=None)
# Out:
# <style type="text/css">
# #T_5c403_row0_col0, #T_5c403_row0_col3, #T_5c403_row3_col0, #T_5c403_row3_col4, #T_5c403_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_5c403_row0_col1, #T_5c403_row1_col0, #T_5c403_row1_col1, #T_5c403_row2_col2, #T_5c403_row3_col3, #T_5c403_row4_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_5c403_row0_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_5c403_row0_col4 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_5c403_row1_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_5c403_row1_col3, #T_5c403_row4_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_5c403_row1_col4, #T_5c403_row3_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_5c403_row2_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_5c403_row2_col1 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_5c403_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5c403_row2_col4 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_5c403_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5c403_row4_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_5c403_row4_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# </style>
# <table id="T_5c403">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_5c403_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_5c403_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_5c403_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_5c403_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_5c403_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c403_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c403_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_5c403_row0_col1" class="data row0 col1" >50.000000</td>
#       <td id="T_5c403_row0_col2" class="data row0 col2" >36.000000</td>
#       <td id="T_5c403_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_5c403_row0_col4" class="data row0 col4" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c403_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5c403_row1_col0" class="data row1 col0" >50.000000</td>
#       <td id="T_5c403_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_5c403_row1_col2" class="data row1 col2" >23.000000</td>
#       <td id="T_5c403_row1_col3" class="data row1 col3" >75.000000</td>
#       <td id="T_5c403_row1_col4" class="data row1 col4" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c403_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5c403_row2_col0" class="data row2 col0" >64.000000</td>
#       <td id="T_5c403_row2_col1" class="data row2 col1" >77.000000</td>
#       <td id="T_5c403_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_5c403_row2_col3" class="data row2 col3" >100.000000</td>
#       <td id="T_5c403_row2_col4" class="data row2 col4" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5c403_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5c403_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_5c403_row3_col1" class="data row3 col1" >25.000000</td>
#       <td id="T_5c403_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_5c403_row3_col3" class="data row3 col3" >50.000000</td>
#       <td id="T_5c403_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_5c403_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5c403_row4_col0" class="data row4 col0" >80.000000</td>
#       <td id="T_5c403_row4_col1" class="data row4 col1" >75.000000</td>
#       <td id="T_5c403_row4_col2" class="data row4 col2" >48.000000</td>
#       <td id="T_5c403_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_5c403_row4_col4" class="data row4 col4" >50.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
(win_counts + loss_counts)
# Out:
# loser_cluster    0    1     2   3     4
# winner_cluster
# 0                0    2    14   0     5
# 1                2   92   456   4   327
# 2               14  456  1626   9   941
# 3                0    4     9  12     0
# 4                5  327   941   0  1576

# %%
data.groupby(['weightclass', 'winner_cluster']).size().unstack(fill_value=0)
# Out:
# winner_cluster     0   1    2  3    4
# weightclass
# bantamweight       0  18  184  0  241
# featherweight      0  35  183  0  192
# flyweight          1  14  112  0  183
# heavyweight        0  26   96  3   84
# light heavyweight  0  14  153  0   79
# lightweight        1  39  338  3  231
# middleweight       3  32  209  1  144
# strawweight        0  12   49  0  135
# welterweight       2  47  345  0  202

# %%
data['weightclass'].value_counts()
# Out:
# weightclass
# lightweight          612
# welterweight         596
# bantamweight         443
# featherweight        410
# middleweight         389
# flyweight            310
# light heavyweight    246
# heavyweight          209
# strawweight          196
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Function to calculate win percentages for a given weight class
def calculate_win_percentage(df):
    win_counts = df.groupby(['winner_cluster', 'loser_cluster']).size().unstack(fill_value=0)
    loss_counts = df.groupby(['loser_cluster', 'winner_cluster']).size().unstack(fill_value=0)
    win_percentage = (win_counts / (win_counts + loss_counts)) * 100
    return win_percentage.round().fillna(0)  # Round and fill NaN with 0

# List of unique weight classes
weight_classes = data['weightclass'].unique()

# Create a dictionary to store win percentages for each weight class
win_percentage_by_weight_class = {}

# Calculate win percentages for each weight class
for weight_class in weight_classes:
    df_filtered = data[data['weightclass'] == weight_class]
    win_percentage_by_weight_class[weight_class] = calculate_win_percentage(df_filtered)

# # Plot each heatmap individually
# for weight_class, win_percentage in win_percentage_by_weight_class.items():
#     plt.figure(figsize=(6, 4))
#     sns.heatmap(win_percentage, annot=True, cmap="Blues", fmt="g", cbar=True)
#     plt.title(f'Win Percentages for Weight Class: {weight_class}')
#     plt.xlabel('Loser Cluster')
#     plt.ylabel('Winner Cluster')
#     plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Function to calculate win percentages for a given weight class
def calculate_win_percentage(df):
    win_counts = df.groupby(['winner_cluster', 'loser_cluster']).size().unstack(fill_value=0)
    loss_counts = df.groupby(['loser_cluster', 'winner_cluster']).size().unstack(fill_value=0)
    win_percentage = (win_counts / (win_counts + loss_counts)) * 100
    return win_percentage.round().fillna(0)  # Round and fill NaN with 0

# List of unique weight classes in the desired order
weight_classes_ordered = ['strawweight', 'flyweight', 'bantamweight', 'featherweight', 
                          'lightweight', 'welterweight', 'middleweight', 
                          'light heavyweight', 'heavyweight']

# Create a dictionary to store win percentages DataFrames for each weight class
win_percentage_df_by_weight_class = {}

# Calculate win percentages for each weight class in the specified order
for weight_class in weight_classes_ordered:
    df_filtered = data[data['weightclass'] == weight_class]
    win_percentage_df_by_weight_class[weight_class] = calculate_win_percentage(df_filtered)

# Display the win percentages as styled DataFrames with background gradient
for weight_class, win_percentage_df in win_percentage_df_by_weight_class.items():
    print(f'Win Percentages for Weight Class: {weight_class}')
    display(win_percentage_df.style.background_gradient(cmap='Blues', axis=None))
    print('\n' + '='*50 + '\n')
# Out:
# Win Percentages for Weight Class: strawweight
# <style type="text/css">
# #T_fc30f_row0_col0, #T_fc30f_row0_col1, #T_fc30f_row0_col2, #T_fc30f_row0_col3, #T_fc30f_row1_col0, #T_fc30f_row1_col1, #T_fc30f_row2_col0, #T_fc30f_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fc30f_row1_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_fc30f_row1_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_fc30f_row2_col1 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_fc30f_row2_col2, #T_fc30f_row3_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_fc30f_row2_col3 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_fc30f_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fc30f_row3_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fc30f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_fc30f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_fc30f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_fc30f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_fc30f_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc30f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc30f_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_fc30f_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_fc30f_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_fc30f_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc30f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc30f_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_fc30f_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_fc30f_row1_col2" class="data row1 col2" >33.000000</td>
#       <td id="T_fc30f_row1_col3" class="data row1 col3" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc30f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc30f_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_fc30f_row2_col1" class="data row2 col1" >67.000000</td>
#       <td id="T_fc30f_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_fc30f_row2_col3" class="data row2 col3" >63.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc30f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_fc30f_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_fc30f_row3_col1" class="data row3 col1" >69.000000</td>
#       <td id="T_fc30f_row3_col2" class="data row3 col2" >37.000000</td>
#       <td id="T_fc30f_row3_col3" class="data row3 col3" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: flyweight
# <style type="text/css">
# #T_15b86_row0_col0, #T_15b86_row0_col1, #T_15b86_row0_col2, #T_15b86_row0_col3, #T_15b86_row1_col0, #T_15b86_row2_col0, #T_15b86_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_15b86_row1_col1, #T_15b86_row2_col2, #T_15b86_row3_col3 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_15b86_row1_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_15b86_row1_col3 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_15b86_row2_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_15b86_row2_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_15b86_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_15b86_row3_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_15b86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15b86_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_15b86_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_15b86_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_15b86_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15b86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15b86_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_15b86_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_15b86_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_15b86_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15b86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15b86_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_15b86_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_15b86_row1_col2" class="data row1 col2" >19.000000</td>
#       <td id="T_15b86_row1_col3" class="data row1 col3" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15b86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_15b86_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_15b86_row2_col1" class="data row2 col1" >81.000000</td>
#       <td id="T_15b86_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_15b86_row2_col3" class="data row2 col3" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15b86_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_15b86_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_15b86_row3_col1" class="data row3 col1" >83.000000</td>
#       <td id="T_15b86_row3_col2" class="data row3 col2" >53.000000</td>
#       <td id="T_15b86_row3_col3" class="data row3 col3" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: bantamweight
# <style type="text/css">
# #T_ad0be_row0_col0, #T_ad0be_row1_col1, #T_ad0be_row2_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_ad0be_row0_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_ad0be_row0_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ad0be_row1_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_ad0be_row1_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_ad0be_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ad0be_row2_col1 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# </style>
# <table id="T_ad0be">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_ad0be_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_ad0be_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_ad0be_level0_col2" class="col_heading level0 col2" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad0be_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ad0be_row0_col0" class="data row0 col0" >50.000000</td>
#       <td id="T_ad0be_row0_col1" class="data row0 col1" >15.000000</td>
#       <td id="T_ad0be_row0_col2" class="data row0 col2" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad0be_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ad0be_row1_col0" class="data row1 col0" >85.000000</td>
#       <td id="T_ad0be_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_ad0be_row1_col2" class="data row1 col2" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ad0be_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_ad0be_row2_col0" class="data row2 col0" >90.000000</td>
#       <td id="T_ad0be_row2_col1" class="data row2 col1" >48.000000</td>
#       <td id="T_ad0be_row2_col2" class="data row2 col2" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: featherweight
# <style type="text/css">
# #T_f10d6_row0_col0, #T_f10d6_row0_col1, #T_f10d6_row0_col2, #T_f10d6_row0_col3, #T_f10d6_row1_col0, #T_f10d6_row2_col0, #T_f10d6_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f10d6_row1_col1, #T_f10d6_row2_col2, #T_f10d6_row3_col3 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_f10d6_row1_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_f10d6_row1_col3 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_f10d6_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f10d6_row2_col3 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_f10d6_row3_col1 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_f10d6_row3_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f10d6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_f10d6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f10d6_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f10d6_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f10d6_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f10d6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f10d6_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_f10d6_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_f10d6_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_f10d6_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f10d6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f10d6_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_f10d6_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_f10d6_row1_col2" class="data row1 col2" >23.000000</td>
#       <td id="T_f10d6_row1_col3" class="data row1 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f10d6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f10d6_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_f10d6_row2_col1" class="data row2 col1" >77.000000</td>
#       <td id="T_f10d6_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_f10d6_row2_col3" class="data row2 col3" >45.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f10d6_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f10d6_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_f10d6_row3_col1" class="data row3 col1" >72.000000</td>
#       <td id="T_f10d6_row3_col2" class="data row3 col2" >55.000000</td>
#       <td id="T_f10d6_row3_col3" class="data row3 col3" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: lightweight
# <style type="text/css">
# #T_34baf_row0_col0, #T_34baf_row0_col2, #T_34baf_row0_col3, #T_34baf_row0_col4, #T_34baf_row1_col0, #T_34baf_row3_col0, #T_34baf_row3_col2, #T_34baf_row3_col4, #T_34baf_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_34baf_row0_col1, #T_34baf_row2_col0, #T_34baf_row2_col3, #T_34baf_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_34baf_row1_col1, #T_34baf_row1_col3, #T_34baf_row2_col2, #T_34baf_row3_col1, #T_34baf_row3_col3, #T_34baf_row4_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_34baf_row1_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_34baf_row1_col4 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_34baf_row2_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_34baf_row2_col4 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_34baf_row4_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_34baf_row4_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# </style>
# <table id="T_34baf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_34baf_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_34baf_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_34baf_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_34baf_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_34baf_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34baf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34baf_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_34baf_row0_col1" class="data row0 col1" >100.000000</td>
#       <td id="T_34baf_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_34baf_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_34baf_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34baf_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_34baf_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_34baf_row1_col2" class="data row1 col2" >24.000000</td>
#       <td id="T_34baf_row1_col3" class="data row1 col3" >50.000000</td>
#       <td id="T_34baf_row1_col4" class="data row1 col4" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34baf_row2_col0" class="data row2 col0" >100.000000</td>
#       <td id="T_34baf_row2_col1" class="data row2 col1" >76.000000</td>
#       <td id="T_34baf_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_34baf_row2_col3" class="data row2 col3" >100.000000</td>
#       <td id="T_34baf_row2_col4" class="data row2 col4" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34baf_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_34baf_row3_col1" class="data row3 col1" >50.000000</td>
#       <td id="T_34baf_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_34baf_row3_col3" class="data row3 col3" >50.000000</td>
#       <td id="T_34baf_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_34baf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34baf_row4_col0" class="data row4 col0" >100.000000</td>
#       <td id="T_34baf_row4_col1" class="data row4 col1" >82.000000</td>
#       <td id="T_34baf_row4_col2" class="data row4 col2" >48.000000</td>
#       <td id="T_34baf_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_34baf_row4_col4" class="data row4 col4" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: welterweight
# <style type="text/css">
# #T_a6f68_row0_col0, #T_a6f68_row0_col1, #T_a6f68_row0_col3, #T_a6f68_row0_col4, #T_a6f68_row1_col3, #T_a6f68_row2_col3, #T_a6f68_row3_col0, #T_a6f68_row3_col1, #T_a6f68_row3_col2, #T_a6f68_row3_col3, #T_a6f68_row3_col4, #T_a6f68_row4_col0, #T_a6f68_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a6f68_row0_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_a6f68_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a6f68_row1_col1, #T_a6f68_row2_col2, #T_a6f68_row4_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_a6f68_row1_col2, #T_a6f68_row1_col4 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_a6f68_row2_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_a6f68_row2_col1, #T_a6f68_row4_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_a6f68_row2_col4 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_a6f68_row4_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# </style>
# <table id="T_a6f68">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_a6f68_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a6f68_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a6f68_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_a6f68_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_a6f68_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6f68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6f68_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_a6f68_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_a6f68_row0_col2" class="data row0 col2" >40.000000</td>
#       <td id="T_a6f68_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a6f68_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6f68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6f68_row1_col0" class="data row1 col0" >100.000000</td>
#       <td id="T_a6f68_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_a6f68_row1_col2" class="data row1 col2" >32.000000</td>
#       <td id="T_a6f68_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a6f68_row1_col4" class="data row1 col4" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6f68_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6f68_row2_col0" class="data row2 col0" >60.000000</td>
#       <td id="T_a6f68_row2_col1" class="data row2 col1" >68.000000</td>
#       <td id="T_a6f68_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_a6f68_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_a6f68_row2_col4" class="data row2 col4" >54.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6f68_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6f68_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_a6f68_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_a6f68_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_a6f68_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_a6f68_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6f68_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6f68_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_a6f68_row4_col1" class="data row4 col1" >68.000000</td>
#       <td id="T_a6f68_row4_col2" class="data row4 col2" >46.000000</td>
#       <td id="T_a6f68_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a6f68_row4_col4" class="data row4 col4" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: middleweight
# <style type="text/css">
# #T_ff8a3_row0_col0, #T_ff8a3_row0_col1, #T_ff8a3_row0_col3, #T_ff8a3_row0_col4, #T_ff8a3_row1_col0, #T_ff8a3_row1_col3, #T_ff8a3_row2_col3, #T_ff8a3_row3_col0, #T_ff8a3_row3_col1, #T_ff8a3_row3_col2, #T_ff8a3_row3_col4, #T_ff8a3_row4_col0, #T_ff8a3_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ff8a3_row0_col2, #T_ff8a3_row1_col1, #T_ff8a3_row2_col0, #T_ff8a3_row2_col2, #T_ff8a3_row2_col4, #T_ff8a3_row3_col3, #T_ff8a3_row4_col2, #T_ff8a3_row4_col4 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_ff8a3_row1_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_ff8a3_row1_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_ff8a3_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ff8a3_row4_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ff8a3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_ff8a3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ff8a3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ff8a3_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_ff8a3_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_ff8a3_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff8a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff8a3_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_ff8a3_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_ff8a3_row0_col2" class="data row0 col2" >50.000000</td>
#       <td id="T_ff8a3_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_ff8a3_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff8a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff8a3_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_ff8a3_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_ff8a3_row1_col2" class="data row1 col2" >17.000000</td>
#       <td id="T_ff8a3_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_ff8a3_row1_col4" class="data row1 col4" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff8a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff8a3_row2_col0" class="data row2 col0" >50.000000</td>
#       <td id="T_ff8a3_row2_col1" class="data row2 col1" >83.000000</td>
#       <td id="T_ff8a3_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_ff8a3_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_ff8a3_row2_col4" class="data row2 col4" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff8a3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff8a3_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_ff8a3_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_ff8a3_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_ff8a3_row3_col3" class="data row3 col3" >50.000000</td>
#       <td id="T_ff8a3_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ff8a3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff8a3_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_ff8a3_row4_col1" class="data row4 col1" >71.000000</td>
#       <td id="T_ff8a3_row4_col2" class="data row4 col2" >50.000000</td>
#       <td id="T_ff8a3_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_ff8a3_row4_col4" class="data row4 col4" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: light heavyweight
# <style type="text/css">
# #T_b7455_row0_col0, #T_b7455_row1_col1, #T_b7455_row2_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_b7455_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b7455_row0_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b7455_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b7455_row1_col2 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_b7455_row2_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_b7455_row2_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# </style>
# <table id="T_b7455">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_b7455_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_b7455_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_b7455_level0_col2" class="col_heading level0 col2" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7455_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b7455_row0_col0" class="data row0 col0" >50.000000</td>
#       <td id="T_b7455_row0_col1" class="data row0 col1" >14.000000</td>
#       <td id="T_b7455_row0_col2" class="data row0 col2" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b7455_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b7455_row1_col0" class="data row1 col0" >86.000000</td>
#       <td id="T_b7455_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_b7455_row1_col2" class="data row1 col2" >53.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b7455_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_b7455_row2_col0" class="data row2 col0" >68.000000</td>
#       <td id="T_b7455_row2_col1" class="data row2 col1" >47.000000</td>
#       <td id="T_b7455_row2_col2" class="data row2 col2" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: heavyweight
# <style type="text/css">
# #T_0fd5f_row0_col0, #T_0fd5f_row1_col1, #T_0fd5f_row2_col2, #T_0fd5f_row3_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_0fd5f_row0_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_0fd5f_row0_col2, #T_0fd5f_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0fd5f_row0_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_0fd5f_row1_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_0fd5f_row1_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_0fd5f_row2_col0, #T_0fd5f_row2_col1, #T_0fd5f_row2_col3, #T_0fd5f_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0fd5f_row3_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_0fd5f_row3_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# </style>
# <table id="T_0fd5f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_0fd5f_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_0fd5f_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_0fd5f_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_0fd5f_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0fd5f_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0fd5f_row0_col0" class="data row0 col0" >50.000000</td>
#       <td id="T_0fd5f_row0_col1" class="data row0 col1" >32.000000</td>
#       <td id="T_0fd5f_row0_col2" class="data row0 col2" >100.000000</td>
#       <td id="T_0fd5f_row0_col3" class="data row0 col3" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0fd5f_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_0fd5f_row1_col0" class="data row1 col0" >68.000000</td>
#       <td id="T_0fd5f_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_0fd5f_row1_col2" class="data row1 col2" >100.000000</td>
#       <td id="T_0fd5f_row1_col3" class="data row1 col3" >57.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0fd5f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_0fd5f_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_0fd5f_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_0fd5f_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_0fd5f_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0fd5f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_0fd5f_row3_col0" class="data row3 col0" >60.000000</td>
#       <td id="T_0fd5f_row3_col1" class="data row3 col1" >43.000000</td>
#       <td id="T_0fd5f_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_0fd5f_row3_col3" class="data row3 col3" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
