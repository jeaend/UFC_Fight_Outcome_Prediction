# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('../2_data_preparation/cleaned_data.csv')
clustered = pd.read_csv('data_clustered.csv')

# %%
clustered = clustered[['name', 'cluster']]
clustered
# Out:
#                    name  cluster
# 0         Lerone Murphy        4
# 1         Edson Barboza        4
# 2        Khaos Williams        4
# 3       Carlston Harris        2
# 4        Themba Gorimbo        2
# ...                 ...      ...
# 2391         Nick Sanzo        3
# 2392         Jim Mullen        3
# 2393  Yoshiki Takahashi        1
# 2394      Wallid Ismail        1
# 2395     Rainy Martinez        3
#
# [2396 rows x 2 columns]

# %%
data['winner'].value_counts()
# Out:
# winner
# f1    7289
# 0      111
# Name: count, dtype: int64

# %%
# filter data where clear decision
data = data[data['winner'] == 'f1']
data['winner'].value_counts()
# Out:
# winner
# f1    7289
# Name: count, dtype: int64

# %%
data['method'].value_counts()
# Out:
# method
# Decision - Unanimous    2645
# KO/TKO                  2443
# Submission              1435
# Decision - Split         766
# Name: count, dtype: int64

# %%
data = data[data['method'].isin(['Decision - Unanimous', 'Decision - Split'])]

# %%
data['method'].value_counts()
# Out:
# method
# Decision - Unanimous    2645
# Decision - Split         766
# Name: count, dtype: int64

# %%
# Merge the cluster column from clustered DataFrame based on fighter names (f1 and f2)
data = pd.merge(data, clustered[['name', 'cluster']], left_on='f1', right_on='name', how='left')
data.rename(columns={'cluster': 'winner_cluster'}, inplace=True)

data = pd.merge(data, clustered[['name', 'cluster']], left_on='f2', right_on='name', how='left')
data.rename(columns={'cluster': 'loser_cluster'}, inplace=True)

# %%
odds_df = data[['winner_cluster', 'loser_cluster']]

# %%
odds_df.head(2)
# Out:
#    winner_cluster  loser_cluster
# 0               4              4
# 1               2              2

# %%
# filter data where clear decision
data = data[data['winner'] == 'f1']
data['winner'].value_counts()
# Out:
# winner
# f1    3411
# Name: count, dtype: int64

# %%
odds_df['winner_cluster'].value_counts()
# Out:
# winner_cluster
# 2    1669
# 4    1491
# 1     237
# 0       7
# 3       7
# Name: count, dtype: int64

# %%
import matplotlib.cm as cm

# Group by winner and loser clusters to count the number of wins and losses
win_counts = odds_df.groupby(['winner_cluster', 'loser_cluster']).size().unstack(fill_value=0)
loss_counts = odds_df.groupby(['loser_cluster', 'winner_cluster']).size().unstack(fill_value=0)

# Calculate win percentage by cluster matchup
win_percentage = (win_counts / (win_counts + loss_counts)) * 100
# Round win percentages to nearest integer
win_percentage_rounded = win_percentage.round()

# Display win percentages by cluster matchup
win_percentage_rounded.style.background_gradient(cmap='Blues', axis=None)
# Out:
# <style type="text/css">
# #T_002bd_row0_col0, #T_002bd_row0_col3, #T_002bd_row3_col0, #T_002bd_row3_col4, #T_002bd_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_002bd_row0_col1, #T_002bd_row1_col0, #T_002bd_row1_col1, #T_002bd_row2_col2, #T_002bd_row3_col3, #T_002bd_row4_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_002bd_row0_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_002bd_row0_col4 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_002bd_row1_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_002bd_row1_col3, #T_002bd_row4_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_002bd_row1_col4, #T_002bd_row3_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_002bd_row2_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_002bd_row2_col1 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_002bd_row2_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_002bd_row2_col4 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_002bd_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_002bd_row4_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_002bd_row4_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# </style>
# <table id="T_002bd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_002bd_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_002bd_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_002bd_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_002bd_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_002bd_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_002bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_002bd_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_002bd_row0_col1" class="data row0 col1" >50.000000</td>
#       <td id="T_002bd_row0_col2" class="data row0 col2" >36.000000</td>
#       <td id="T_002bd_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_002bd_row0_col4" class="data row0 col4" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_002bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_002bd_row1_col0" class="data row1 col0" >50.000000</td>
#       <td id="T_002bd_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_002bd_row1_col2" class="data row1 col2" >23.000000</td>
#       <td id="T_002bd_row1_col3" class="data row1 col3" >75.000000</td>
#       <td id="T_002bd_row1_col4" class="data row1 col4" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_002bd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_002bd_row2_col0" class="data row2 col0" >64.000000</td>
#       <td id="T_002bd_row2_col1" class="data row2 col1" >77.000000</td>
#       <td id="T_002bd_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_002bd_row2_col3" class="data row2 col3" >100.000000</td>
#       <td id="T_002bd_row2_col4" class="data row2 col4" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_002bd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_002bd_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_002bd_row3_col1" class="data row3 col1" >25.000000</td>
#       <td id="T_002bd_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_002bd_row3_col3" class="data row3 col3" >50.000000</td>
#       <td id="T_002bd_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_002bd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_002bd_row4_col0" class="data row4 col0" >80.000000</td>
#       <td id="T_002bd_row4_col1" class="data row4 col1" >75.000000</td>
#       <td id="T_002bd_row4_col2" class="data row4 col2" >48.000000</td>
#       <td id="T_002bd_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_002bd_row4_col4" class="data row4 col4" >50.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
(win_counts + loss_counts)
# Out:
# loser_cluster    0    1     2   3     4
# winner_cluster
# 0                0    2    14   0     5
# 1                2   92   456   4   327
# 2               14  456  1626   9   941
# 3                0    4     9  12     0
# 4                5  327   941   0  1576

# %%
data.groupby(['weightclass', 'winner_cluster']).size().unstack(fill_value=0)
# Out:
# winner_cluster     0   1    2  3    4
# weightclass
# bantamweight       0  18  184  0  241
# featherweight      0  35  183  0  192
# flyweight          1  14  112  0  183
# heavyweight        0  26   96  3   84
# light heavyweight  0  14  153  0   79
# lightweight        1  39  338  3  231
# middleweight       3  32  209  1  144
# strawweight        0  12   49  0  135
# welterweight       2  47  345  0  202

# %%
data['weightclass'].value_counts()
# Out:
# weightclass
# lightweight          612
# welterweight         596
# bantamweight         443
# featherweight        410
# middleweight         389
# flyweight            310
# light heavyweight    246
# heavyweight          209
# strawweight          196
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Function to calculate win percentages for a given weight class
def calculate_win_percentage(df):
    win_counts = df.groupby(['winner_cluster', 'loser_cluster']).size().unstack(fill_value=0)
    loss_counts = df.groupby(['loser_cluster', 'winner_cluster']).size().unstack(fill_value=0)
    win_percentage = (win_counts / (win_counts + loss_counts)) * 100
    return win_percentage.round().fillna(0)  # Round and fill NaN with 0

# List of unique weight classes
weight_classes = data['weightclass'].unique()

# Create a dictionary to store win percentages for each weight class
win_percentage_by_weight_class = {}

# Calculate win percentages for each weight class
for weight_class in weight_classes:
    df_filtered = data[data['weightclass'] == weight_class]
    win_percentage_by_weight_class[weight_class] = calculate_win_percentage(df_filtered)

# # Plot each heatmap individually
# for weight_class, win_percentage in win_percentage_by_weight_class.items():
#     plt.figure(figsize=(6, 4))
#     sns.heatmap(win_percentage, annot=True, cmap="Blues", fmt="g", cbar=True)
#     plt.title(f'Win Percentages for Weight Class: {weight_class}')
#     plt.xlabel('Loser Cluster')
#     plt.ylabel('Winner Cluster')
#     plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Function to calculate win percentages for a given weight class
def calculate_win_percentage(df):
    win_counts = df.groupby(['winner_cluster', 'loser_cluster']).size().unstack(fill_value=0)
    loss_counts = df.groupby(['loser_cluster', 'winner_cluster']).size().unstack(fill_value=0)
    win_percentage = (win_counts / (win_counts + loss_counts)) * 100
    return win_percentage.round().fillna(0)  # Round and fill NaN with 0

# List of unique weight classes in the desired order
weight_classes_ordered = ['strawweight', 'flyweight', 'bantamweight', 'featherweight', 
                          'lightweight', 'welterweight', 'middleweight', 
                          'light heavyweight', 'heavyweight']

# Create a dictionary to store win percentages DataFrames for each weight class
win_percentage_df_by_weight_class = {}

# Calculate win percentages for each weight class in the specified order
for weight_class in weight_classes_ordered:
    df_filtered = data[data['weightclass'] == weight_class]
    win_percentage_df_by_weight_class[weight_class] = calculate_win_percentage(df_filtered)

# Display the win percentages as styled DataFrames with background gradient
for weight_class, win_percentage_df in win_percentage_df_by_weight_class.items():
    print(f'Win Percentages for Weight Class: {weight_class}')
    display(win_percentage_df.style.background_gradient(cmap='Blues', axis=None))
    print('\n' + '='*50 + '\n')
# Out:
# Win Percentages for Weight Class: strawweight
# <style type="text/css">
# #T_b6b6d_row0_col0, #T_b6b6d_row0_col1, #T_b6b6d_row0_col2, #T_b6b6d_row0_col3, #T_b6b6d_row1_col0, #T_b6b6d_row1_col1, #T_b6b6d_row2_col0, #T_b6b6d_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b6b6d_row1_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_b6b6d_row1_col3 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_b6b6d_row2_col1 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_b6b6d_row2_col2, #T_b6b6d_row3_col3 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_b6b6d_row2_col3 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_b6b6d_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b6b6d_row3_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6b6d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_b6b6d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b6b6d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b6b6d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b6b6d_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6b6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6b6d_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_b6b6d_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_b6b6d_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_b6b6d_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b6b6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6b6d_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_b6b6d_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_b6b6d_row1_col2" class="data row1 col2" >33.000000</td>
#       <td id="T_b6b6d_row1_col3" class="data row1 col3" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b6b6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6b6d_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_b6b6d_row2_col1" class="data row2 col1" >67.000000</td>
#       <td id="T_b6b6d_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_b6b6d_row2_col3" class="data row2 col3" >63.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b6b6d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b6b6d_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_b6b6d_row3_col1" class="data row3 col1" >69.000000</td>
#       <td id="T_b6b6d_row3_col2" class="data row3 col2" >37.000000</td>
#       <td id="T_b6b6d_row3_col3" class="data row3 col3" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: flyweight
# <style type="text/css">
# #T_a239f_row0_col0, #T_a239f_row0_col1, #T_a239f_row0_col2, #T_a239f_row0_col3, #T_a239f_row1_col0, #T_a239f_row2_col0, #T_a239f_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a239f_row1_col1, #T_a239f_row2_col2, #T_a239f_row3_col3 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_a239f_row1_col2 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_a239f_row1_col3 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_a239f_row2_col1 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_a239f_row2_col3 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_a239f_row3_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a239f_row3_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a239f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a239f_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a239f_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a239f_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_a239f_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a239f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a239f_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_a239f_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_a239f_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_a239f_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a239f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a239f_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_a239f_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_a239f_row1_col2" class="data row1 col2" >19.000000</td>
#       <td id="T_a239f_row1_col3" class="data row1 col3" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a239f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a239f_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_a239f_row2_col1" class="data row2 col1" >81.000000</td>
#       <td id="T_a239f_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_a239f_row2_col3" class="data row2 col3" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a239f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a239f_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_a239f_row3_col1" class="data row3 col1" >83.000000</td>
#       <td id="T_a239f_row3_col2" class="data row3 col2" >53.000000</td>
#       <td id="T_a239f_row3_col3" class="data row3 col3" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: bantamweight
# <style type="text/css">
# #T_e0dcd_row0_col0, #T_e0dcd_row1_col1, #T_e0dcd_row2_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_e0dcd_row0_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_e0dcd_row0_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e0dcd_row1_col0 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_e0dcd_row1_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_e0dcd_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e0dcd_row2_col1 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# </style>
# <table id="T_e0dcd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_e0dcd_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_e0dcd_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_e0dcd_level0_col2" class="col_heading level0 col2" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0dcd_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e0dcd_row0_col0" class="data row0 col0" >50.000000</td>
#       <td id="T_e0dcd_row0_col1" class="data row0 col1" >15.000000</td>
#       <td id="T_e0dcd_row0_col2" class="data row0 col2" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e0dcd_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_e0dcd_row1_col0" class="data row1 col0" >85.000000</td>
#       <td id="T_e0dcd_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_e0dcd_row1_col2" class="data row1 col2" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e0dcd_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_e0dcd_row2_col0" class="data row2 col0" >90.000000</td>
#       <td id="T_e0dcd_row2_col1" class="data row2 col1" >48.000000</td>
#       <td id="T_e0dcd_row2_col2" class="data row2 col2" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: featherweight
# <style type="text/css">
# #T_ee851_row0_col0, #T_ee851_row0_col1, #T_ee851_row0_col2, #T_ee851_row0_col3, #T_ee851_row1_col0, #T_ee851_row2_col0, #T_ee851_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ee851_row1_col1, #T_ee851_row2_col2, #T_ee851_row3_col3 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_ee851_row1_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_ee851_row1_col3 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_ee851_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ee851_row2_col3 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_ee851_row3_col1 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_ee851_row3_col2 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ee851">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_ee851_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_ee851_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_ee851_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_ee851_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee851_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee851_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_ee851_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_ee851_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_ee851_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ee851_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ee851_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_ee851_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_ee851_row1_col2" class="data row1 col2" >23.000000</td>
#       <td id="T_ee851_row1_col3" class="data row1 col3" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ee851_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ee851_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_ee851_row2_col1" class="data row2 col1" >77.000000</td>
#       <td id="T_ee851_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_ee851_row2_col3" class="data row2 col3" >45.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ee851_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ee851_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_ee851_row3_col1" class="data row3 col1" >72.000000</td>
#       <td id="T_ee851_row3_col2" class="data row3 col2" >55.000000</td>
#       <td id="T_ee851_row3_col3" class="data row3 col3" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: lightweight
# <style type="text/css">
# #T_73b66_row0_col0, #T_73b66_row0_col2, #T_73b66_row0_col3, #T_73b66_row0_col4, #T_73b66_row1_col0, #T_73b66_row3_col0, #T_73b66_row3_col2, #T_73b66_row3_col4, #T_73b66_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_73b66_row0_col1, #T_73b66_row2_col0, #T_73b66_row2_col3, #T_73b66_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_73b66_row1_col1, #T_73b66_row1_col3, #T_73b66_row2_col2, #T_73b66_row3_col1, #T_73b66_row3_col3, #T_73b66_row4_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_73b66_row1_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_73b66_row1_col4 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_73b66_row2_col1 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_73b66_row2_col4 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_73b66_row4_col1 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_73b66_row4_col2 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# </style>
# <table id="T_73b66">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_73b66_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_73b66_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_73b66_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_73b66_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_73b66_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73b66_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73b66_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_73b66_row0_col1" class="data row0 col1" >100.000000</td>
#       <td id="T_73b66_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_73b66_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_73b66_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73b66_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73b66_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_73b66_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_73b66_row1_col2" class="data row1 col2" >24.000000</td>
#       <td id="T_73b66_row1_col3" class="data row1 col3" >50.000000</td>
#       <td id="T_73b66_row1_col4" class="data row1 col4" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73b66_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73b66_row2_col0" class="data row2 col0" >100.000000</td>
#       <td id="T_73b66_row2_col1" class="data row2 col1" >76.000000</td>
#       <td id="T_73b66_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_73b66_row2_col3" class="data row2 col3" >100.000000</td>
#       <td id="T_73b66_row2_col4" class="data row2 col4" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73b66_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73b66_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_73b66_row3_col1" class="data row3 col1" >50.000000</td>
#       <td id="T_73b66_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_73b66_row3_col3" class="data row3 col3" >50.000000</td>
#       <td id="T_73b66_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_73b66_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73b66_row4_col0" class="data row4 col0" >100.000000</td>
#       <td id="T_73b66_row4_col1" class="data row4 col1" >82.000000</td>
#       <td id="T_73b66_row4_col2" class="data row4 col2" >48.000000</td>
#       <td id="T_73b66_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_73b66_row4_col4" class="data row4 col4" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: welterweight
# <style type="text/css">
# #T_3d54e_row0_col0, #T_3d54e_row0_col1, #T_3d54e_row0_col3, #T_3d54e_row0_col4, #T_3d54e_row1_col3, #T_3d54e_row2_col3, #T_3d54e_row3_col0, #T_3d54e_row3_col1, #T_3d54e_row3_col2, #T_3d54e_row3_col3, #T_3d54e_row3_col4, #T_3d54e_row4_col0, #T_3d54e_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3d54e_row0_col2 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_3d54e_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3d54e_row1_col1, #T_3d54e_row2_col2, #T_3d54e_row4_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_3d54e_row1_col2, #T_3d54e_row1_col4 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_3d54e_row2_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_3d54e_row2_col1, #T_3d54e_row4_col1 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_3d54e_row2_col4 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_3d54e_row4_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# </style>
# <table id="T_3d54e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_3d54e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3d54e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_3d54e_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_3d54e_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_3d54e_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d54e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d54e_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_3d54e_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_3d54e_row0_col2" class="data row0 col2" >40.000000</td>
#       <td id="T_3d54e_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_3d54e_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d54e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d54e_row1_col0" class="data row1 col0" >100.000000</td>
#       <td id="T_3d54e_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_3d54e_row1_col2" class="data row1 col2" >32.000000</td>
#       <td id="T_3d54e_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_3d54e_row1_col4" class="data row1 col4" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d54e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d54e_row2_col0" class="data row2 col0" >60.000000</td>
#       <td id="T_3d54e_row2_col1" class="data row2 col1" >68.000000</td>
#       <td id="T_3d54e_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_3d54e_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_3d54e_row2_col4" class="data row2 col4" >54.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d54e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d54e_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_3d54e_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_3d54e_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_3d54e_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_3d54e_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d54e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d54e_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_3d54e_row4_col1" class="data row4 col1" >68.000000</td>
#       <td id="T_3d54e_row4_col2" class="data row4 col2" >46.000000</td>
#       <td id="T_3d54e_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_3d54e_row4_col4" class="data row4 col4" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: middleweight
# <style type="text/css">
# #T_b5173_row0_col0, #T_b5173_row0_col1, #T_b5173_row0_col3, #T_b5173_row0_col4, #T_b5173_row1_col0, #T_b5173_row1_col3, #T_b5173_row2_col3, #T_b5173_row3_col0, #T_b5173_row3_col1, #T_b5173_row3_col2, #T_b5173_row3_col4, #T_b5173_row4_col0, #T_b5173_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b5173_row0_col2, #T_b5173_row1_col1, #T_b5173_row2_col0, #T_b5173_row2_col2, #T_b5173_row2_col4, #T_b5173_row3_col3, #T_b5173_row4_col2, #T_b5173_row4_col4 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_b5173_row1_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b5173_row1_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_b5173_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b5173_row4_col1 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b5173">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_b5173_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_b5173_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_b5173_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_b5173_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_b5173_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5173_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5173_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_b5173_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_b5173_row0_col2" class="data row0 col2" >50.000000</td>
#       <td id="T_b5173_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_b5173_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5173_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b5173_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_b5173_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_b5173_row1_col2" class="data row1 col2" >17.000000</td>
#       <td id="T_b5173_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_b5173_row1_col4" class="data row1 col4" >29.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5173_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b5173_row2_col0" class="data row2 col0" >50.000000</td>
#       <td id="T_b5173_row2_col1" class="data row2 col1" >83.000000</td>
#       <td id="T_b5173_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_b5173_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_b5173_row2_col4" class="data row2 col4" >50.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5173_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b5173_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_b5173_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_b5173_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_b5173_row3_col3" class="data row3 col3" >50.000000</td>
#       <td id="T_b5173_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_b5173_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b5173_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_b5173_row4_col1" class="data row4 col1" >71.000000</td>
#       <td id="T_b5173_row4_col2" class="data row4 col2" >50.000000</td>
#       <td id="T_b5173_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_b5173_row4_col4" class="data row4 col4" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: light heavyweight
# <style type="text/css">
# #T_aecc1_row0_col0, #T_aecc1_row1_col1, #T_aecc1_row2_col2 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_aecc1_row0_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_aecc1_row0_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_aecc1_row1_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_aecc1_row1_col2 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_aecc1_row2_col0 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_aecc1_row2_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# </style>
# <table id="T_aecc1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_aecc1_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_aecc1_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_aecc1_level0_col2" class="col_heading level0 col2" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aecc1_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_aecc1_row0_col0" class="data row0 col0" >50.000000</td>
#       <td id="T_aecc1_row0_col1" class="data row0 col1" >14.000000</td>
#       <td id="T_aecc1_row0_col2" class="data row0 col2" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aecc1_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_aecc1_row1_col0" class="data row1 col0" >86.000000</td>
#       <td id="T_aecc1_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_aecc1_row1_col2" class="data row1 col2" >53.000000</td>
#     </tr>
#     <tr>
#       <th id="T_aecc1_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_aecc1_row2_col0" class="data row2 col0" >68.000000</td>
#       <td id="T_aecc1_row2_col1" class="data row2 col1" >47.000000</td>
#       <td id="T_aecc1_row2_col2" class="data row2 col2" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================
#
# Win Percentages for Weight Class: heavyweight
# <style type="text/css">
# #T_1d0b9_row0_col0, #T_1d0b9_row1_col1, #T_1d0b9_row2_col2, #T_1d0b9_row3_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_1d0b9_row0_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_1d0b9_row0_col2, #T_1d0b9_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1d0b9_row0_col3 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_1d0b9_row1_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_1d0b9_row1_col3 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_1d0b9_row2_col0, #T_1d0b9_row2_col1, #T_1d0b9_row2_col3, #T_1d0b9_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1d0b9_row3_col0 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_1d0b9_row3_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# </style>
# <table id="T_1d0b9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >loser_cluster</th>
#       <th id="T_1d0b9_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_1d0b9_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_1d0b9_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_1d0b9_level0_col3" class="col_heading level0 col3" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >winner_cluster</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d0b9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1d0b9_row0_col0" class="data row0 col0" >50.000000</td>
#       <td id="T_1d0b9_row0_col1" class="data row0 col1" >32.000000</td>
#       <td id="T_1d0b9_row0_col2" class="data row0 col2" >100.000000</td>
#       <td id="T_1d0b9_row0_col3" class="data row0 col3" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1d0b9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1d0b9_row1_col0" class="data row1 col0" >68.000000</td>
#       <td id="T_1d0b9_row1_col1" class="data row1 col1" >50.000000</td>
#       <td id="T_1d0b9_row1_col2" class="data row1 col2" >100.000000</td>
#       <td id="T_1d0b9_row1_col3" class="data row1 col3" >57.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1d0b9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1d0b9_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_1d0b9_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_1d0b9_row2_col2" class="data row2 col2" >50.000000</td>
#       <td id="T_1d0b9_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1d0b9_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_1d0b9_row3_col0" class="data row3 col0" >60.000000</td>
#       <td id="T_1d0b9_row3_col1" class="data row3 col1" >43.000000</td>
#       <td id="T_1d0b9_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_1d0b9_row3_col3" class="data row3 col3" >50.000000</td>
#     </tr>
#   </tbody>
# </table>
# ==================================================

# %% [markdown]
# > add to df to be able to visualize in tableau

# %%
import pandas as pd

# Assuming data is your original DataFrame
# Group by winner and loser clusters to count the number of wins and losses
win_counts = data.groupby(['winner_cluster', 'loser_cluster']).size().unstack(fill_value=0)
loss_counts = data.groupby(['loser_cluster', 'winner_cluster']).size().unstack(fill_value=0)

# Calculate win percentage by cluster matchup
win_percentage = (win_counts / (win_counts + loss_counts)) * 100
# Round win percentages to nearest integer
win_percentage_rounded = win_percentage.round().fillna(0)  # Fill NaN with 0 for cases with no matches

# Reset index and melt the DataFrame to make it long-form
win_percentage_melted = win_percentage_rounded.reset_index().melt(id_vars='winner_cluster', var_name='loser_cluster', value_name='win_percentage')

# Merge the win percentage data with the original data
data_with_win_percentages = pd.merge(
    data, 
    win_percentage_melted, 
    how='left', 
    left_on=['winner_cluster', 'loser_cluster'], 
    right_on=['winner_cluster', 'loser_cluster']
)

# Check the merged DataFrame
display(data_with_win_percentages.head())

# Save the DataFrame to a CSV file for visualization in Tableau
data_with_win_percentages.to_csv('data_with_win_percentages.csv', index=False)
# Out:
#   end_time                  f1                  f2  fight_date  \
# 0     5:00       Lerone Murphy       Edson Barboza  2024-05-18
# 1     5:00      Themba Gorimbo      Ramiz Brahimaj  2024-05-18
# 2     5:00      Abus Magomedov       Warlley Alves  2024-05-18
# 3     5:00        Alatengheili  Kleydson Rodrigues  2024-05-18
# 4     5:00  Vanessa Demopoulos        Emily Ducote  2024-05-18
#
#                  method          referee  round  time_format    weightclass  \
# 0  Decision - Unanimous        Herb Dean      5            5  featherweight
# 1  Decision - Unanimous       Mark Smith      3            3   welterweight
# 2  Decision - Unanimous  Dan Miragliotta      3            3   middleweight
# 3  Decision - Unanimous        Herb Dean      3            3   bantamweight
# 4      Decision - Split    Chris Tognoni      3            3    strawweight
#
#   winner   f1_body f1_clinch f1_control f1_distance        f1_dob f1_ground  \
# 0     f1  27 of 34  13 of 17       5:19  205 of 344  Jul 22, 1991    2 of 3
# 1     f1  31 of 35  35 of 38      10:13     6 of 10  Jan 23, 1991    2 of 4
# 2     f1   7 of 11    2 of 2      11:56     9 of 27  Sep 02, 1990  11 of 15
# 3     f1    3 of 8    0 of 0       8:16    15 of 53  Dec 14, 1991    3 of 6
# 4     f1  18 of 25    3 of 4       0:00  106 of 289  Sep 22, 1988    0 of 0
#
#       f1_head  f1_height  f1_kd    f1_leg  f1_reach       f1_record  f1_rev  \
# 0  172 of 308     175.26      0  21 of 22    185.42  Record: 14-0-1       0
# 1     9 of 13     185.42      0    3 of 4    195.58  Record: 13-4-0       1
# 2    15 of 32     187.96      0    0 of 1    198.12  Record: 26-6-1       0
# 3    14 of 50     165.10      0    1 of 1    167.64  Record: 17-9-2       0
# 4   76 of 250     157.48      0  15 of 18    149.86  Record: 11-5-0       0
#
#    f1_sapm  f1_sig_str f1_sig_str_%  f1_slpm f1_stance f1_str__acc_  \
# 0     2.60  220 of 364          60%     5.01  Orthodox          54%
# 1     1.08    43 of 52          82%     2.53  Orthodox          69%
# 2     3.73    22 of 44          50%     2.88  Orthodox          44%
# 3     4.67    18 of 59          30%     2.64  Orthodox          32%
# 4     5.69  109 of 293          37%     3.98  Orthodox          41%
#
#   f1_str__def  f1_sub__avg_  f1_sub_att   f1_td f1_td_% f1_td_acc_  \
# 0         60%           0.6           0  4 of 6     66%        52%
# 1         46%           0.0           0  5 of 6     83%        58%
# 2         55%           0.0           0  6 of 7     85%        77%
# 3         57%           0.0           0  3 of 4     75%        45%
# 4         41%           0.6           0  0 of 3      0%        11%
#
#    f1_td_avg_ f1_td_def_ f1_total_str  f1_weight   f2_body f2_clinch  \
# 0        1.59        46%   259 of 410      65.77  15 of 21    2 of 3
# 1        4.04        78%   110 of 134      77.11    3 of 4    3 of 4
# 2        2.65       100%    98 of 168      83.91    4 of 4    0 of 1
# 3        1.99        75%   107 of 183      61.23  10 of 15    0 of 0
# 4        0.42        30%   126 of 311      52.16  22 of 26    0 of 0
#
#   f2_control f2_distance        f2_dob f2_ground    f2_head  f2_height  f2_kd  \
# 0       5:19   77 of 239  Jan 21, 1986    0 of 0  38 of 189     180.34      0
# 1      10:13      0 of 2  Nov 17, 1992    0 of 0     0 of 2     177.80      0
# 2      11:56    16 of 37  Jan 04, 1991    0 of 0    7 of 26     180.34      0
# 3       8:16    37 of 88  Oct 22, 1995    0 of 0   15 of 55     165.10      0
# 4       0:00  140 of 211  Jan 01, 1994    3 of 3  86 of 150     157.48      0
#
#      f2_leg  f2_reach        f2_record  f2_rev  f2_sapm  f2_sig_str  \
# 0  26 of 32    190.50  Record: 24-12-0       0     4.65   79 of 242
# 1    0 of 0    182.88   Record: 10-5-0       0     3.69      3 of 6
# 2    5 of 8    182.88   Record: 15-8-0       0     3.95    16 of 38
# 3  12 of 18    170.18    Record: 8-4-0       0     2.29    37 of 88
# 4  35 of 38    160.02   Record: 13-9-0       0     7.84  143 of 214
#
#   f2_sig_str_%  f2_slpm f2_stance f2_str__acc_ f2_str__def  f2_sub__avg_  \
# 0          32%     4.11  Orthodox          44%         56%           0.1
# 1          50%     1.74  Orthodox          41%         45%           1.6
# 2          42%     3.04  Orthodox          48%         50%           0.8
# 3          42%     4.58  Orthodox          57%         53%           0.6
# 4          66%     7.45  Orthodox          52%         57%           0.0
#
#    f2_sub_att   f2_td f2_td_% f2_td_acc_  f2_td_avg_ f2_td_def_ f2_total_str  \
# 0           0  0 of 0       0        50%        0.45        72%    79 of 242
# 1           0  1 of 8     12%        35%        1.61        44%     15 of 20
# 2           0  0 of 0       0        50%        1.22        62%     17 of 39
# 3           0  0 of 1      0%        22%        0.60        53%    70 of 126
# 4           0  0 of 0       0        14%        0.20        94%   147 of 218
#
#    f2_weight gender  year              name_x  winner_cluster  \
# 0      65.77      M  2024       Lerone Murphy               4
# 1      77.11      M  2024      Themba Gorimbo               2
# 2      83.91      M  2024      Abus Magomedov               2
# 3      61.23      M  2024        Alatengheili               2
# 4      52.16      M  2024  Vanessa Demopoulos               1
#
#                name_y loser_cluster  win_percentage
# 0       Edson Barboza             4            50.0
# 1      Ramiz Brahimaj             2            50.0
# 2       Warlley Alves             2            50.0
# 3  Kleydson Rodrigues             4            52.0
# 4        Emily Ducote             4            25.0
