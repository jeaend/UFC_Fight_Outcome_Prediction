# %%
import pandas as pd
import numpy as np
import re
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("ufc_data_merged.csv")

# %%
# Changes suffix to prefix 
def fix_suffix_to_prefix(column_name):
    column_name = column_name.lower().replace('.', '_').replace(':', '').replace(' ', '_')
    if column_name.endswith('_f1') or column_name.endswith('_f2'):
        suffix = column_name[-3:]
        prefix = 'f1_' if suffix == '_f1' else 'f2_'
        return prefix + column_name[:-3]
    elif '_f1_' in column_name:
        return column_name.replace('_f1_', '_')
    elif '_f2_' in column_name:
        return column_name.replace('_f2_', '_')
    else:
        return column_name

# Sorts columns
def custom_sort(column_name):
    if not column_name.startswith('f1_') and not column_name.startswith('f2_'):
        return (0, column_name)
    elif column_name.startswith('f1_'):
        return (1, column_name)
    else:
        return (2, column_name)

# %%
# Fix formatting colummn names
data.columns = [fix_suffix_to_prefix(col) for col in data.columns]
# Sort columns
sorted_columns = sorted(data.columns, key=custom_sort)
data = data[sorted_columns]

# %%
# Drop list for redundant, and unneccesary columns
drop_list = []
data.head(2)
# Out:
#                              card_name end_time              f1  \
# 0  UFC Fight Night: Barboza vs. Murphy     5:00   Lerone Murphy
# 1  UFC Fight Night: Barboza vs. Murphy     1:30  Khaos Williams
#
#                 f2    fight_date         fights_location  \
# 0    Edson Barboza  May 18, 2024  Las Vegas, Nevada, USA
# 1  Carlston Harris  May 18, 2024  Las Vegas, Nevada, USA
#
#                  method          referee  round time_format  \
# 0  Decision - Unanimous        Herb Dean      5           5
# 1                KO/TKO  Dan Miragliotta      1           3
#
#           weightclass          winner   f1_body f1_clinch f1_control  \
# 0  Featherweight Bout   Lerone Murphy  27 of 34  13 of 17       5:19
# 1   Welterweight Bout  Khaos Williams    2 of 4    0 of 0       0:01
#
#   f1_distance        f1_dob      f1_fighter f1_ground     f1_head f1_height  \
# 0  205 of 344  Jul 22, 1991   Lerone Murphy    2 of 3  172 of 308     5' 9"
# 1    11 of 19  Mar 30, 1994  Khaos Williams    1 of 1      5 of 9     6' 0"
#
#    f1_kd    f1_leg f1_reach       f1_record  f1_rev  f1_sapm  f1_sig_str  \
# 0      0  21 of 22      73"  Record: 14-0-1       0     2.60  220 of 364
# 1      1    5 of 7      77"  Record: 15-3-0       0     5.42    12 of 20
#
#   f1_sig_str_%  f1_slpm f1_stance f1_str__acc_ f1_str__def  f1_sub__avg_  \
# 0          60%     5.01  Orthodox          54%         60%           0.6
# 1          60%     5.81  Orthodox          39%         42%           0.0
#
#    f1_sub_att   f1_td f1_td_% f1_td_acc_  f1_td_avg_ f1_td_def_ f1_total_str  \
# 0           0  4 of 6     66%        52%        1.59        46%   259 of 410
# 1           0  0 of 0     ---         0%        0.00        80%     12 of 20
#
#    f1_unnamed_11                                             f1_url f1_weight  \
# 0            NaN  http://www.ufcstats.com/fighter-details/396fe8...  145 lbs.
# 1            NaN  http://www.ufcstats.com/fighter-details/2558ae...  170 lbs.
#
#     f2_body f2_clinch f2_control f2_distance        f2_dob       f2_fighter  \
# 0  15 of 21    2 of 3       0:17   77 of 239  Jan 21, 1986    Edson Barboza
# 1    1 of 2    0 of 0       0:00    14 of 30  Jul 09, 1987  Carlston Harris
#
#   f2_ground    f2_head f2_height  f2_kd    f2_leg f2_reach        f2_record  \
# 0    0 of 0  38 of 189    5' 11"      0  26 of 32      75"  Record: 24-12-0
# 1    0 of 0   10 of 25     6' 0"      0    3 of 3      76"   Record: 19-6-0
#
#    f2_rev  f2_sapm f2_sig_str f2_sig_str_%  f2_slpm f2_stance f2_str__acc_  \
# 0       0     4.65  79 of 242          32%     4.11  Orthodox          44%
# 1       0     2.66   14 of 30          46%     3.18  Orthodox          49%
#
#   f2_str__def  f2_sub__avg_  f2_sub_att   f2_td f2_td_% f2_td_acc_  \
# 0         56%           0.1           0  0 of 0     ---        50%
# 1         52%           0.8           0  0 of 0     ---        29%
#
#    f2_td_avg_ f2_td_def_ f2_total_str  f2_unnamed_11  \
# 0        0.45        72%    79 of 242            NaN
# 1        1.97        55%     14 of 30            NaN
#
#                                               f2_url f2_weight
# 0  http://www.ufcstats.com/fighter-details/64a50d...  145 lbs.
# 1  http://www.ufcstats.com/fighter-details/a53d30...  170 lbs.

# %%
data['winner'] = np.where(data['winner'] != '0', 'f1', data['winner'])

# %%
data['winner'].value_counts()
# Out:
# winner
# f1    7506
# 0      143
# Name: count, dtype: int64

# %%
drop_list += ['f1', 'f2', 'fights_location', 'f1_fighter', 'f1_unnamed_11', 'f1_url', 'f2_fighter', 'f2_unnamed_11', 'f2_url', 'card_name']

# %%
data.drop(columns=drop_list, inplace=True)

# %% [markdown]
# #### filtering data before looking at the acutal value since there are some issues with record with old fights, since they are less relevant I will remove them

# %%
weightclass_pattern = re.compile(r"(light\s)?(\w+weight)")

def parse_weightclass(weightclass):
    matches = re.findall(weightclass_pattern, weightclass)
    if not matches:
        return "other"
    else:
        return  ''.join(matches[0])

def parse_gender(weightclass):    
    return 'F' if 'women' in weightclass.lower() else 'M'

# %%
data['weightclass'] = data['weightclass'].str.lower()
data['weightclass'] = data['weightclass'].apply(parse_weightclass)
data['gender'] = data['weightclass'].apply(parse_gender)
data['weightclass'] = data[data['weightclass'] != 'other'][['weightclass']]

# %%
data['weightclass'].value_counts(dropna=False)
# Out:
# weightclass
# lightweight          1319
# welterweight         1276
# middleweight         1009
# bantamweight          867
# featherweight         768
# heavyweight           701
# light heavyweight     685
# flyweight             557
# strawweight           301
# NaN                   166
# Name: count, dtype: int64

# %%
# Convert "fight_date" column to datetime format
data['fight_date'] = pd.to_datetime(data['fight_date'])

# Extract year from the "fight_date" column
data['year'] = data['fight_date'].dt.year

weightclass_counts = data.pivot_table(index='year', columns='weightclass', aggfunc='size', fill_value=0)

# Display the DataFrame
display(weightclass_counts)
display(weightclass_counts.shape)
weightclass_counts.columns
# Out:
# weightclass  bantamweight  featherweight  flyweight  heavyweight  \
# year
# 1997                    0              0          0           26
# 1998                    0              0          0            6
# 1999                    0              0          0           20
# 2000                    0              0          0           13
# 2001                    0              0          0           10
# 2002                    0              0          0           11
# 2003                    0              0          0           13
# 2004                    0              0          0            7
# 2005                    0              0          0           14
# 2006                    0              0          0           26
# 2007                    0              0          0           16
# 2008                    0              0          0           23
# 2009                    0              0          0           24
# 2010                    1              3          0           32
# 2011                   40             42          0           24
# 2012                   38             54         13           27
# 2013                   53             49         22           28
# 2014                   77             61         34           32
# 2015                   57             56         36           28
# 2016                   67             50         24           40
# 2017                   55             48         39           39
# 2018                   64             63         47           34
# 2019                   84             64         53           40
# 2020                   68             63         56           44
# 2021                   78             64         68           39
# 2022                   76             60         65           36
# 2023                   74             64         72           35
# 2024                   35             27         28           14
#
# weightclass  light heavyweight  lightweight  middleweight  strawweight  \
# year
# 1997                         1           11             1            0
# 1998                         3            3             8            0
# 1999                         1            6            13            0
# 2000                         2            7            12            0
# 2001                         8            7             5            0
# 2002                         9            8            12            0
# 2003                         5            9             7            0
# 2004                         6            6             8            0
# 2005                        15            0            26            0
# 2006                        33           19            36            0
# 2007                        31           53            28            0
# 2008                        30           56            46            0
# 2009                        36           58            36            0
# 2010                        34           65            53            0
# 2011                        34           63            42            0
# 2012                        27           69            47            0
# 2013                        33           75            56            0
# 2014                        31          107            61           13
# 2015                        26          100            56           24
# 2016                        39           88            57           27
# 2017                        40           70            56           34
# 2018                        38           72            44           32
# 2019                        46           76            46           30
# 2020                        36           51            44           26
# 2021                        37           64            64           31
# 2022                        35           66            64           34
# 2023                        35           77            56           35
# 2024                        14           33            25           15
#
# weightclass  welterweight
# year
# 1997                    0
# 1998                    1
# 1999                    2
# 2000                    9
# 2001                   10
# 2002                   13
# 2003                    7
# 2004                   12
# 2005                   25
# 2006                   42
# 2007                   43
# 2008                   45
# 2009                   57
# 2010                   65
# 2011                   54
# 2012                   64
# 2013                   70
# 2014                   85
# 2015                   88
# 2016                   95
# 2017                   73
# 2018                   80
# 2019                   76
# 2020                   55
# 2021                   60
# 2022                   62
# 2023                   61
# 2024                   22
# (28, 9)
# Index(['bantamweight', 'featherweight', 'flyweight', 'heavyweight',
#        'light heavyweight', 'lightweight', 'middleweight', 'strawweight',
#        'welterweight'],
#       dtype='object', name='weightclass')

# %%
data.shape
# Out:
# (7649, 68)

# %%
data.isna().sum()[data.isna().sum() > 0]
# Out:
# referee         24
# weightclass    166
# f1_stance       11
# f2_stance       66
# dtype: int64

# %%
data.isna().sum().sum()
# Out:
# 267

# %%
# Concatenate 'f1_stance' and 'f2_stance' columns
combined_stance = pd.concat([data['f1_stance'], data['f2_stance']])
combined_stance_mode = combined_stance.mode()[0]

# Fill NaN values in both 'f1_stance' and 'f2_stance' with combined_stance_mode
data['f1_stance'].fillna(combined_stance_mode, inplace=True)
data['f2_stance'].fillna(combined_stance_mode, inplace=True)

# %%
data[data['referee'].isna()]
# old fight, can be dropped
# Out:
#      end_time fight_date                method referee  round time_format  \
# 2381     5:00 2019-09-07  Decision - Unanimous     NaN      3           3
# 2524     1:59 2019-06-01            Submission     NaN      2           3
# 2622     5:00 2019-03-23  Decision - Unanimous     NaN      3           3
# 2928     5:00 2018-07-28  Decision - Unanimous     NaN      3           3
# 3042     5:00 2018-05-19      Decision - Split     NaN      3           3
# 3047     5:00 2018-05-19  Decision - Unanimous     NaN      3           3
# 3082     5:00 2018-04-14  Decision - Unanimous     NaN      3           3
# 3573     0:30 2017-03-18                KO/TKO     NaN      1           3
# 4044     3:44 2016-04-10                KO/TKO     NaN      1           3
# 4078     5:00 2016-02-27  Decision - Unanimous     NaN      3           3
# 4082     5:00 2016-02-27  Decision - Unanimous     NaN      3           3
# 4125     5:00 2016-01-17      Decision - Split     NaN      3           3
# 4166     5:00 2015-12-12  Decision - Unanimous     NaN      3           3
# 4449     2:38 2015-05-23            Submission     NaN      2           3
# 4457     3:56 2015-05-16            Submission     NaN      1           3
# 4779     2:04 2014-09-13            Submission     NaN      2           3
# 5038     4:33 2014-03-15            Submission     NaN      1           3
# 5039     5:00 2014-03-15  Decision - Unanimous     NaN      3           3
# 5210     5:00 2013-10-26  Decision - Unanimous     NaN      3           3
# 5289     5:00 2013-08-17  Decision - Unanimous     NaN      3           3
# 5293     3:43 2013-08-17            Submission     NaN      2           3
# 5435     5:00 2013-03-16  Decision - Unanimous     NaN      3           3
# 5789     3:53 2012-03-02                KO/TKO     NaN      2           3
# 7460     5:00 1999-09-24   Decision - Majority     NaN      2           2
#
#         weightclass winner   f1_body f1_clinch f1_control f1_distance  \
# 2381   middleweight     f1   5 of 10    0 of 2       3:39    21 of 67
# 2524   bantamweight     f1    5 of 6    0 of 0       1:09    18 of 69
# 2622      flyweight     f1  12 of 12  11 of 15       1:18   49 of 113
# 2928    lightweight     f1  15 of 24  17 of 25       7:11    10 of 37
# 3042   welterweight     f1    4 of 7    1 of 4       2:44    29 of 72
# 3047   bantamweight     f1  18 of 22  16 of 19       4:10    40 of 84
# 3082      flyweight     f1  20 of 29    4 of 7       2:48   54 of 147
# 3573    lightweight     f1    2 of 2    0 of 0       0:01      6 of 7
# 4044    lightweight     f1    1 of 5    0 of 0       0:01    25 of 59
# 4078   bantamweight     f1  14 of 18  16 of 22       8:37    33 of 58
# 4082    lightweight     f1    2 of 3    2 of 2       4:35    15 of 62
# 4125    lightweight     f1  12 of 18    3 of 4       7:38    36 of 82
# 4166  featherweight     f1  12 of 17    6 of 8       3:27    42 of 81
# 4449    lightweight     f1    3 of 4   9 of 14       3:00    17 of 29
# 4457    lightweight     f1    4 of 4    2 of 4       1:02     9 of 23
# 4779   bantamweight     f1    3 of 3    1 of 2       1:19    12 of 26
# 5038   middleweight     f1    2 of 5    2 of 2       2:35     7 of 16
# 5039  featherweight     f1   9 of 12   6 of 11       7:45    17 of 34
# 5210    lightweight     f1  15 of 21    5 of 8       2:54   75 of 184
# 5289   bantamweight     f1    1 of 1    0 of 0      10:08      3 of 7
# 5293   bantamweight     f1    4 of 5    5 of 9       0:29    43 of 73
# 5435    lightweight     f1  12 of 29    3 of 3       3:39   36 of 123
#      f2_ground    f2_head f2_height  f2_kd    f2_leg f2_reach  \
# 2381    0 of 0    6 of 51     6' 0"      0   9 of 11      75"
# 2524    2 of 2   36 of 90     5' 7"      0    4 of 6      73"
# 2622    1 of 1   16 of 54     5' 6"      0  28 of 31      68"
# 2928    1 of 1    8 of 18     5' 9"      0    2 of 3      70"
# 3042    0 of 0   12 of 64     6' 0"      0    5 of 7      75"
# 3047    0 of 0   25 of 82     5' 8"      0    9 of 9      69"
# 3082    0 of 0  34 of 158     5' 6"      0  11 of 12      69"
# 3573    0 of 0     0 of 0     6' 1"      0    0 of 0      75"
# 4044    0 of 0    9 of 40     5' 9"      0    1 of 1      70"
# 4078   4 of 10    9 of 46     5' 8"      0    1 of 1      70"
# 4082    2 of 3    6 of 53    5' 11"      0   7 of 11      70"
# 4125    0 of 0   33 of 79    5' 10"      0  10 of 10      72"
# 4166    0 of 0   12 of 55     5' 9"      0  24 of 26      71"
# 4449    0 of 0    2 of 14    5' 10"      0    4 of 7       --
# 4457    0 of 0    6 of 24     5' 9"      0    3 of 5      71"
# 4779    6 of 6    4 of 15    5' 10"      0    0 of 0      71"
# 5038    0 of 0     1 of 5     6' 3"      0    1 of 1      75"
# 5039   9 of 10    7 of 25     5' 7"      0    9 of 9      69"
# 5210    1 of 1  40 of 133     5' 9"      0   8 of 15      71"
# 5289   6 of 13    5 of 17     5' 9"      0    0 of 1      71"
# 5293   4 of 10   16 of 73     5' 6"      0    1 of 3      68"
# 5435    2 of 3   11 of 59     6' 2"      0  16 of 43       --
# 5789    0 of 0   15 of 48     6' 1"      0    8 of 8      75"
# 7460  10 of 12   32 of 62     5' 3"      0   9 of 10       --
#
#                    f2_record  f2_rev  f2_sapm f2_sig_str f2_sig_str_%  \
# 2381          Record: 25-7-0       0     2.91   17 of 69          24%
# 2524           Record: 3-1-0       0     2.72  42 of 106          39%
# 2622         Record: 21-11-0       0     4.45  72 of 122          59%
# 2928          Record: 11-5-0       0     2.97   19 of 32          59%
# 3042          Record: 25-7-0       0     2.91   28 of 92          30%
# 3047          Record: 16-8-1       0     4.68  44 of 104          42%
# 3082           Record: 4-5-0       0     5.20  68 of 206          33%
# 3573           Record: 8-3-0       0     3.91     1 of 1         100%
# 4044          Record: 14-7-0       0     3.26   11 of 43          25%
# 4078          Record: 23-9-1       0     5.48   23 of 66          34%
# 4082          Record: 23-6-1       0     2.88   17 of 72          23%
# 4125         Record: 24-10-0       0     3.44  56 of 109          51%
# 4166  Record: 28-19-0 (1 NC)       0     3.05   47 of 95          49%
# 4449          Record: 18-4-1       0     3.80    7 of 25          28%
# 4457         Record: 18-10-0       0     2.07   12 of 34          35%
# 4779  Record: 21-13-1 (1 NC)       0     1.75    9 of 20          45%
# 5038         Record: 28-10-0       0     1.98    4 of 10          40%
# 5039  Record: 28-15-0 (3 NC)       0     3.18   24 of 44          54%
# 5210          Record: 18-6-0       0     3.17  66 of 176          37%
# 5289  Record: 35-10-0 (1 NC)       0     2.79    8 of 23          34%
# 5435   0 of 2      0%         0%        0.00        27%    61 of 152
# 5789   0 of 1      0%         0%        0.00        50%     32 of 66
# 7460   0 of 1      0%         0%        0.00         0%    69 of 105
#
#      f2_weight gender  year
# 2381  205 lbs.      M  2019
# 2524  145 lbs.      M  2019
# 2622  135 lbs.      M  2019
# 2928  155 lbs.      M  2018
# 3042  205 lbs.      M  2018
# 3047  135 lbs.      M  2018
# 3082  125 lbs.      M  2018
# 3573  155 lbs.      M  2017
# 4044  155 lbs.      M  2016
# 4078  135 lbs.      M  2016
# 4082  155 lbs.      M  2016
# 4125  155 lbs.      M  2016
# 4166  145 lbs.      M  2015
# 4449  155 lbs.      M  2015
# 4457  155 lbs.      M  2015
# 4779  135 lbs.      M  2014
# 5038  185 lbs.      M  2014
# 5039  145 lbs.      M  2014
# 5210  155 lbs.      M  2013
# 5289  135 lbs.      M  2013
# 5293  135 lbs.      M  2013
# 5435  155 lbs.      M  2013
# 5789  242 lbs.      M  2012
# 7460  145 lbs.      M  1999

# %%
data.dropna(how='any', inplace=True)

# %%
data['method'].value_counts()
# Out:
# method
# Decision - Unanimous       2652
# KO/TKO                     2364
# Submission                 1438
# Decision - Split            724
# Decision - Majority          91
# TKO - Doctor's Stoppage      83
# Overturned                   56
# Could Not Continue           28
# DQ                           23
# Name: count, dtype: int64

# %%
# Replace values according to the specified mapping
data['method'] = data['method'].replace({
    "TKO - Doctor's Stoppage": 'KO/TKO',
    "Decision - Majority": 'Decision - Split',
    "Overturned": 'Decision - Split',
    "Could Not Continue": 'Stopped',
    "DQ": 'Stopped'
})

# %%
data['method'].value_counts()
# filter out stopped
# Out:
# method
# Decision - Unanimous    2652
# KO/TKO                  2447
# Submission              1438
# Decision - Split         871
# Stopped                   51
# Name: count, dtype: int64

# %%
data = data[~data['method'].isin(['Stopped'])]
data
# Out:
#      end_time fight_date                method          referee  round  \
# 0        5:00 2024-05-18  Decision - Unanimous        Herb Dean      5
# 1        1:30 2024-05-18                KO/TKO  Dan Miragliotta      1
# 2        5:00 2024-05-18  Decision - Unanimous       Mark Smith      3
# 3        2:47 2024-05-18                KO/TKO    Chris Tognoni      1
# 4        4:12 2024-05-18            Submission        Herb Dean      2
# ...       ...        ...                   ...              ...    ...
# 7545     0:39 1997-02-07            Submission    John McCarthy      1
# 7546     1:17 1997-02-07                KO/TKO    John McCarthy      1
# 7547     8:02 1997-02-07                KO/TKO    John McCarthy      1
# 7548     3:00 1997-02-07  Decision - Unanimous    John McCarthy      2
# 7549     1:24 1997-02-07            Submission    John McCarthy      1
#
#      time_format    weightclass winner   f1_body f1_clinch f1_control  \
# 0              5  featherweight     f1  27 of 34  13 of 17       5:19
# 1              3   welterweight     f1    2 of 4    0 of 0       0:01
# 2              3   welterweight     f1  31 of 35  35 of 38      10:13
# 3              3   bantamweight     f1    1 of 2    0 of 0       0:17
# 4              3    strawweight     f1   9 of 15    3 of 3       3:06
# ...          ...            ...    ...       ...       ...        ...
# 7545           1    lightweight     f1    0 of 0    2 of 2         --
# 7546           1    heavyweight     f1    0 of 0   5 of 15         --
# 7547           1    heavyweight     f1    6 of 6  11 of 17         --
# 7548           1    lightweight     f1    0 of 0    3 of 6         --
# 7549           1    lightweight     f1    0 of 0    0 of 0         --
#
#      f1_distance        f1_dob f1_ground     f1_head f1_height  f1_kd  \
# 0     205 of 344  Jul 22, 1991    2 of 3  172 of 308     5' 9"      0
# 1       11 of 19  Mar 30, 1994    1 of 1      5 of 9     6' 0"      1
# 2        6 of 10  Jan 23, 1991    2 of 4     9 of 13     6' 1"      0
# 3       15 of 28  Nov 29, 1993  21 of 28    27 of 45     5' 7"      1
# 4       21 of 71  Jan 12, 1985    4 of 5    19 of 64     5' 3"      0
# ...          ...           ...       ...         ...       ...    ...
# 7545      0 of 2  Feb 12, 1974    0 of 0      2 of 3    5' 11"      0
# 7546      2 of 4  Apr 01, 1977  10 of 10    17 of 29     6' 0"      1
# 7547      2 of 3  Apr 26, 1965  17 of 22    23 of 35    5' 11"      0
# 7548     9 of 27  Mar 13, 1969   8 of 10    20 of 43    5' 11"      0
# 7549      0 of 3  Feb 12, 1974    0 of 0      0 of 0    5' 11"      0
#
#         f1_leg f1_reach               f1_record  f1_rev  f1_sapm  f1_sig_str  \
# 0     21 of 22      73"          Record: 14-0-1       0     2.60  220 of 364
# 1       5 of 7      77"          Record: 15-3-0       0     5.42    12 of 20
# 2       3 of 4      77"          Record: 13-4-0       1     1.08    43 of 52
# 3       8 of 9      70"          Record: 17-5-0       0     5.75    36 of 56
# 4       0 of 0      64"         Record: 17-13-0       1     4.86    28 of 79
# ...        ...      ...                     ...     ...      ...         ...
# 7545    0 of 1       --          Record: 11-4-0       0     0.00      2 of 4
# 7546    0 of 0      74"  Record: 26-14-0 (1 NC)       0     2.83    17 of 29
# 7547    1 of 1       --           Record: 4-2-0       0     0.00    30 of 42
# 7548    0 of 0       --  Record: 30-27-3 (1 NC)       0     6.47    20 of 43
# 7549    0 of 3       --          Record: 11-4-0       0     0.00      0 of 3
#
#      f1_sig_str_%  f1_slpm f1_stance f1_str__acc_ f1_str__def  f1_sub__avg_  \
# 0             60%     5.01  Orthodox          54%         60%           0.6
# 1             60%     5.81  Orthodox          39%         42%           0.0
# 2             82%     2.53  Orthodox          69%         46%           0.0
# 3             64%     6.51  Orthodox          41%         57%           0.0
# 4             35%     5.38  Orthodox          49%         61%           0.1
# ...           ...      ...       ...          ...         ...           ...
# 7545          50%     0.00  Orthodox           0%          0%           0.0
# 7546          58%     1.59  Southpaw          46%         50%           0.6
# 7547          71%     0.00  Orthodox           0%          0%           0.0
# 7548          46%     2.26  Southpaw          51%         44%           2.3
# 7549           0%     0.00  Orthodox           0%          0%           0.0
#
#       f1_sub_att   f1_td f1_td_% f1_td_acc_  f1_td_avg_ f1_td_def_  \
# 0              0  4 of 6     66%        52%        1.59        46%
# 1              0  0 of 0     ---         0%        0.00        80%
# 2              0  5 of 6     83%        58%        4.04        78%
# 3              0  0 of 0     ---         0%        0.00       100%
# 4              1  2 of 6     33%        33%        0.80        76%
# ...          ...     ...     ...        ...         ...        ...
# 7545           1  1 of 1    100%         0%        0.00         0%
# 7546           0  0 of 0     ---        60%        1.02        53%
# 7547           1  2 of 2    100%         0%        0.00         0%
# 7548           0  1 of 1    100%         0%        0.00        66%
# 7549           1  1 of 1    100%         0%        0.00         0%
#
#      f1_total_str f1_weight   f2_body f2_clinch f2_control f2_distance  \
# 0      259 of 410  145 lbs.  15 of 21    2 of 3       0:17   77 of 239
# 1        12 of 20  170 lbs.    1 of 2    0 of 0       0:00    14 of 30
# 2      110 of 134  170 lbs.    3 of 4    3 of 4       3:44      0 of 2
# 3        36 of 58  135 lbs.    6 of 6    0 of 0       0:00    17 of 34
# 4        39 of 91  115 lbs.    3 of 6    2 of 6       0:04    15 of 54
# ...           ...       ...       ...       ...        ...         ...
# 7545       3 of 5  199 lbs.    0 of 0    0 of 0         --      0 of 0
# 7546     23 of 35  185 lbs.    1 of 1    1 of 6         --      0 of 1
# 7547     63 of 78  323 lbs.    0 of 0    2 of 2         --      1 of 3
# 7548     72 of 99  199 lbs.    0 of 0    0 of 0         --     1 of 17
# 7549       4 of 7  199 lbs.    0 of 0    0 of 0         --      0 of 0
#
#             f2_dob f2_ground    f2_head f2_height  f2_kd    f2_leg f2_reach  \
# 0     Jan 21, 1986    0 of 0  38 of 189    5' 11"      0  26 of 32      75"
# 1     Jul 09, 1987    0 of 0   10 of 25     6' 0"      0    3 of 3      76"
# 2     Nov 17, 1992    0 of 0     0 of 2    5' 10"      0    0 of 0      72"
# 3     Jul 24, 1996    0 of 0    6 of 20     5' 7"      0    5 of 8      70"
# 4     Nov 18, 1992    0 of 0   11 of 51     5' 2"      0    3 of 3      62"
# ...            ...       ...        ...       ...    ...       ...      ...
# 7545            --    0 of 0     0 of 0     5' 9"      0    0 of 0       --
# 7546  Feb 07, 1965    0 of 0     0 of 6     6' 2"      0    0 of 0       --
# 7547            --    0 of 0     3 of 5     6' 1"      0    0 of 0       --
# 7548  Feb 23, 1968    0 of 0    1 of 17     5' 7"      0    0 of 0       --
# 7549            --    0 of 0     0 of 0     6' 0"      0    0 of 0       --
#
#             f2_record  f2_rev  f2_sapm f2_sig_str f2_sig_str_%  f2_slpm  \
# 0     Record: 24-12-0       0     4.65  79 of 242          32%     4.11
# 1      Record: 19-6-0       0     2.66   14 of 30          46%     3.18
# 2      Record: 10-5-0       0     3.69     3 of 6          50%     1.74
# 3      Record: 14-7-0       0     6.50   17 of 34          50%     5.48
# 4      Record: 11-3-0       0     4.17   17 of 60          28%     3.57
# ...               ...     ...      ...        ...          ...      ...
# 7545    Record: 1-1-0       0     0.00     0 of 0          ---     0.00
# 7546    Record: 7-5-1       0     3.02     1 of 7          14%     1.83
# 7547    Record: 0-2-0       0     0.00     3 of 5          60%     0.00
# 7548    Record: 9-3-0       0     0.83    1 of 17           5%     0.92
# 7549    Record: 0-2-0       0     0.00     0 of 0          ---     0.00
#
#      f2_stance f2_str__acc_ f2_str__def  f2_sub__avg_  f2_sub_att    f2_td  \
# 0     Orthodox          44%         56%           0.1           0   0 of 0
# 1     Orthodox          49%         52%           0.8           0   0 of 0
# 2     Orthodox          41%         45%           1.6           0   1 of 8
# 3     Southpaw          43%         48%           0.0           0   0 of 0
# 4     Orthodox          40%         63%           0.2           0   1 of 7
# ...        ...          ...         ...           ...         ...      ...
# 7545  Orthodox           0%          0%           0.0           0   0 of 1
# 7546  Orthodox          35%         56%           0.0           0   0 of 0
# 7547  Southpaw           0%          0%           0.0           0   0 of 0
# 7548  Orthodox          31%         44%           0.5           0  1 of 10
# 7549  Orthodox           0%          0%           0.0           0   0 of 0
#
#      f2_td_% f2_td_acc_  f2_td_avg_ f2_td_def_ f2_total_str f2_weight gender  \
# 0        ---        50%        0.45        72%    79 of 242  145 lbs.      M
# 1        ---        29%        1.97        55%     14 of 30  170 lbs.      M
# 2        12%        35%        1.61        44%     15 of 20  170 lbs.      M
# 3        ---        11%        0.36        86%     17 of 34  135 lbs.      M
# 4        14%        33%        2.24        66%     25 of 77  115 lbs.      M
# ...      ...        ...         ...        ...          ...       ...    ...
# 7545      0%         0%        0.00         0%       0 of 0  190 lbs.      M
# 7546     ---       100%        0.87        80%       1 of 7  233 lbs.      M
# 7547     ---         0%        0.00         0%       4 of 7  215 lbs.      M
# 7548     10%        28%        1.85         0%     19 of 38  205 lbs.      M
# 7549     ---         0%        0.00         0%       0 of 0  199 lbs.      M
#
#       year
# 0     2024
# 1     2024
# 2     2024
# 3     2024
# 4     2024
# ...    ...
# 7545  1997
# 7546  1997
# 7547  1997
# 7548  1997
# 7549  1997
#
# [7408 rows x 68 columns]

# %%
data['f1_control'] = data['f1_control'].replace({
    "--": 0,
})
data['f2_control'] = data['f1_control'].replace({
    "--": 0,
})

# %%
data['f1_reach'].value_counts(dropna=False)
# Out:
# f1_reach
# 70"    710
# 75"    640
# 73"    621
# 71"    620
# 74"    620
# 72"    616
# 76"    484
# 77"    379
# 68"    371
# 69"    335
# 67"    304
# 66"    246
# 78"    230
# --     220
# 65"    216
# 79"    185
# 80"    163
# 64"    127
# 63"     94
# 81"     45
# 62"     43
# 84"     41
# 82"     37
# 61"     21
# 83"     19
# 60"     12
# 59"      5
# 58"      4
# Name: count, dtype: int64

# %%
# Convert to centimeters
def inches_to_cm(height_str):
    # Use regular expression to extract feet and inches
    match = re.match(r"(\d+)\'\s*(\d+)\"|(\d+)\"", height_str)
    if match:
        feet = int(match.group(1)) if match.group(1) else 0
        inches = int(match.group(2)) if match.group(2) else int(match.group(3))
        total_inches = feet * 12 + inches
        return total_inches * 2.54
    else:
        return None

# %%
data
# Out:
#      end_time fight_date                method          referee  round  \
# 0        5:00 2024-05-18  Decision - Unanimous        Herb Dean      5
# 1        1:30 2024-05-18                KO/TKO  Dan Miragliotta      1
# 2        5:00 2024-05-18  Decision - Unanimous       Mark Smith      3
# 3        2:47 2024-05-18                KO/TKO    Chris Tognoni      1
# 4        4:12 2024-05-18            Submission        Herb Dean      2
# ...       ...        ...                   ...              ...    ...
# 7545     0:39 1997-02-07            Submission    John McCarthy      1
# 7546     1:17 1997-02-07                KO/TKO    John McCarthy      1
# 7547     8:02 1997-02-07                KO/TKO    John McCarthy      1
# 7548     3:00 1997-02-07  Decision - Unanimous    John McCarthy      2
# 7549     1:24 1997-02-07            Submission    John McCarthy      1
#
#      time_format    weightclass winner   f1_body f1_clinch f1_control  \
# 0              5  featherweight     f1  27 of 34  13 of 17       5:19
# 1              3   welterweight     f1    2 of 4    0 of 0       0:01
# 2              3   welterweight     f1  31 of 35  35 of 38      10:13
# 3              3   bantamweight     f1    1 of 2    0 of 0       0:17
# 4              3    strawweight     f1   9 of 15    3 of 3       3:06
# ...          ...            ...    ...       ...       ...        ...
# 7545           1    lightweight     f1    0 of 0    2 of 2          0
# 7546           1    heavyweight     f1    0 of 0   5 of 15          0
# 7547           1    heavyweight     f1    6 of 6  11 of 17          0
# 7548           1    lightweight     f1    0 of 0    3 of 6          0
# 7549           1    lightweight     f1    0 of 0    0 of 0          0
#
#      f1_distance        f1_dob f1_ground     f1_head f1_height  f1_kd  \
# 0     205 of 344  Jul 22, 1991    2 of 3  172 of 308     5' 9"      0
# 1       11 of 19  Mar 30, 1994    1 of 1      5 of 9     6' 0"      1
# 2        6 of 10  Jan 23, 1991    2 of 4     9 of 13     6' 1"      0
# 3       15 of 28  Nov 29, 1993  21 of 28    27 of 45     5' 7"      1
# 4       21 of 71  Jan 12, 1985    4 of 5    19 of 64     5' 3"      0
# ...          ...           ...       ...         ...       ...    ...
# 7545      0 of 2  Feb 12, 1974    0 of 0      2 of 3    5' 11"      0
# 7546      2 of 4  Apr 01, 1977  10 of 10    17 of 29     6' 0"      1
# 7547      2 of 3  Apr 26, 1965  17 of 22    23 of 35    5' 11"      0
# 7548     9 of 27  Mar 13, 1969   8 of 10    20 of 43    5' 11"      0
# 7549      0 of 3  Feb 12, 1974    0 of 0      0 of 0    5' 11"      0
#
#         f1_leg f1_reach               f1_record  f1_rev  f1_sapm  f1_sig_str  \
# 0     21 of 22      73"          Record: 14-0-1       0     2.60  220 of 364
# 1       5 of 7      77"          Record: 15-3-0       0     5.42    12 of 20
# 2       3 of 4      77"          Record: 13-4-0       1     1.08    43 of 52
# 3       8 of 9      70"          Record: 17-5-0       0     5.75    36 of 56
# 4       0 of 0      64"         Record: 17-13-0       1     4.86    28 of 79
# ...        ...      ...                     ...     ...      ...         ...
# 7545    0 of 1       --          Record: 11-4-0       0     0.00      2 of 4
# 7546    0 of 0      74"  Record: 26-14-0 (1 NC)       0     2.83    17 of 29
# 7547    1 of 1       --           Record: 4-2-0       0     0.00    30 of 42
# 7548    0 of 0       --  Record: 30-27-3 (1 NC)       0     6.47    20 of 43
# 7549    0 of 3       --          Record: 11-4-0       0     0.00      0 of 3
#
#      f1_sig_str_%  f1_slpm f1_stance f1_str__acc_ f1_str__def  f1_sub__avg_  \
# 0             60%     5.01  Orthodox          54%         60%           0.6
# 1             60%     5.81  Orthodox          39%         42%           0.0
# 2             82%     2.53  Orthodox          69%         46%           0.0
# 3             64%     6.51  Orthodox          41%         57%           0.0
# 4             35%     5.38  Orthodox          49%         61%           0.1
# ...           ...      ...       ...          ...         ...           ...
# 7545          50%     0.00  Orthodox           0%          0%           0.0
# 7546          58%     1.59  Southpaw          46%         50%           0.6
# 7547          71%     0.00  Orthodox           0%          0%           0.0
# 7548          46%     2.26  Southpaw          51%         44%           2.3
# 7549           0%     0.00  Orthodox           0%          0%           0.0
#
#       f1_sub_att   f1_td f1_td_% f1_td_acc_  f1_td_avg_ f1_td_def_  \
# 0              0  4 of 6     66%        52%        1.59        46%
# 1              0  0 of 0     ---         0%        0.00        80%
# 2              0  5 of 6     83%        58%        4.04        78%
# 3              0  0 of 0     ---         0%        0.00       100%
# 4              1  2 of 6     33%        33%        0.80        76%
# ...          ...     ...     ...        ...         ...        ...
# 7545           1  1 of 1    100%         0%        0.00         0%
# 7546           0  0 of 0     ---        60%        1.02        53%
# 7547           1  2 of 2    100%         0%        0.00         0%
# 7548           0  1 of 1    100%         0%        0.00        66%
# 7549           1  1 of 1    100%         0%        0.00         0%
#
#      f1_total_str f1_weight   f2_body f2_clinch f2_control f2_distance  \
# 0      259 of 410  145 lbs.  15 of 21    2 of 3       5:19   77 of 239
# 1        12 of 20  170 lbs.    1 of 2    0 of 0       0:01    14 of 30
# 2      110 of 134  170 lbs.    3 of 4    3 of 4      10:13      0 of 2
# 3        36 of 58  135 lbs.    6 of 6    0 of 0       0:17    17 of 34
# 4        39 of 91  115 lbs.    3 of 6    2 of 6       3:06    15 of 54
# ...           ...       ...       ...       ...        ...         ...
# 7545       3 of 5  199 lbs.    0 of 0    0 of 0          0      0 of 0
# 7546     23 of 35  185 lbs.    1 of 1    1 of 6          0      0 of 1
# 7547     63 of 78  323 lbs.    0 of 0    2 of 2          0      1 of 3
# 7548     72 of 99  199 lbs.    0 of 0    0 of 0          0     1 of 17
# 7549       4 of 7  199 lbs.    0 of 0    0 of 0          0      0 of 0
#
#             f2_dob f2_ground    f2_head f2_height  f2_kd    f2_leg f2_reach  \
# 0     Jan 21, 1986    0 of 0  38 of 189    5' 11"      0  26 of 32      75"
# 1     Jul 09, 1987    0 of 0   10 of 25     6' 0"      0    3 of 3      76"
# 2     Nov 17, 1992    0 of 0     0 of 2    5' 10"      0    0 of 0      72"
# 3     Jul 24, 1996    0 of 0    6 of 20     5' 7"      0    5 of 8      70"
# 4     Nov 18, 1992    0 of 0   11 of 51     5' 2"      0    3 of 3      62"
# ...            ...       ...        ...       ...    ...       ...      ...
# 7545            --    0 of 0     0 of 0     5' 9"      0    0 of 0       --
# 7546  Feb 07, 1965    0 of 0     0 of 6     6' 2"      0    0 of 0       --
# 7547            --    0 of 0     3 of 5     6' 1"      0    0 of 0       --
# 7548  Feb 23, 1968    0 of 0    1 of 17     5' 7"      0    0 of 0       --
# 7549            --    0 of 0     0 of 0     6' 0"      0    0 of 0       --
#
#             f2_record  f2_rev  f2_sapm f2_sig_str f2_sig_str_%  f2_slpm  \
# 0     Record: 24-12-0       0     4.65  79 of 242          32%     4.11
# 1      Record: 19-6-0       0     2.66   14 of 30          46%     3.18
# 2      Record: 10-5-0       0     3.69     3 of 6          50%     1.74
# 3      Record: 14-7-0       0     6.50   17 of 34          50%     5.48
# 4      Record: 11-3-0       0     4.17   17 of 60          28%     3.57
# ...               ...     ...      ...        ...          ...      ...
# 7545    Record: 1-1-0       0     0.00     0 of 0          ---     0.00
# 7546    Record: 7-5-1       0     3.02     1 of 7          14%     1.83
# 7547    Record: 0-2-0       0     0.00     3 of 5          60%     0.00
# 7548    Record: 9-3-0       0     0.83    1 of 17           5%     0.92
# 7549    Record: 0-2-0       0     0.00     0 of 0          ---     0.00
#
#      f2_stance f2_str__acc_ f2_str__def  f2_sub__avg_  f2_sub_att    f2_td  \
# 0     Orthodox          44%         56%           0.1           0   0 of 0
# 1     Orthodox          49%         52%           0.8           0   0 of 0
# 2     Orthodox          41%         45%           1.6           0   1 of 8
# 3     Southpaw          43%         48%           0.0           0   0 of 0
# 4     Orthodox          40%         63%           0.2           0   1 of 7
# ...        ...          ...         ...           ...         ...      ...
# 7545  Orthodox           0%          0%           0.0           0   0 of 1
# 7546  Orthodox          35%         56%           0.0           0   0 of 0
# 7547  Southpaw           0%          0%           0.0           0   0 of 0
# 7548  Orthodox          31%         44%           0.5           0  1 of 10
# 7549  Orthodox           0%          0%           0.0           0   0 of 0
#
#      f2_td_% f2_td_acc_  f2_td_avg_ f2_td_def_ f2_total_str f2_weight gender  \
# 0        ---        50%        0.45        72%    79 of 242  145 lbs.      M
# 1        ---        29%        1.97        55%     14 of 30  170 lbs.      M
# 2        12%        35%        1.61        44%     15 of 20  170 lbs.      M
# 3        ---        11%        0.36        86%     17 of 34  135 lbs.      M
# 4        14%        33%        2.24        66%     25 of 77  115 lbs.      M
# ...      ...        ...         ...        ...          ...       ...    ...
# 7545      0%         0%        0.00         0%       0 of 0  190 lbs.      M
# 7546     ---       100%        0.87        80%       1 of 7  233 lbs.      M
# 7547     ---         0%        0.00         0%       4 of 7  215 lbs.      M
# 7548     10%        28%        1.85         0%     19 of 38  205 lbs.      M
# 7549     ---         0%        0.00         0%       0 of 0  199 lbs.      M
#
#       year
# 0     2024
# 1     2024
# 2     2024
# 3     2024
# 4     2024
# ...    ...
# 7545  1997
# 7546  1997
# 7547  1997
# 7548  1997
# 7549  1997
#
# [7408 rows x 68 columns]

# %%
data['f1_height'] = data['f1_height'].apply(inches_to_cm)
data['f2_height'] = data['f2_height'].apply(inches_to_cm)
data['f1_reach'] = data['f1_reach'].apply(inches_to_cm)
data['f2_reach'] = data['f2_reach'].apply(inches_to_cm)

# %%
data['f1_height'].corr(data['f1_reach'])
# let's fill the -- with a modeled approach
# Out:
# 0.8986037184852236
